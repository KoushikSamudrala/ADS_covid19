# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import matplotlib as mpl
import plotly.graph_objects as go

import plotly.express as px

pd.set_option('display.max_rows',500)

# %% [markdown]
# # Data preparation

# %%
#laoding data from url
url="https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
df=pd.read_csv(url)

# %%
#inspecting data frame
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 197243      ZWE    Africa     Zimbabwe  2022-06-23     255136.0       87.0
# 197244      ZWE    Africa     Zimbabwe  2022-06-24     255309.0      173.0
# 197245      ZWE    Africa     Zimbabwe  2022-06-25     255309.0        0.0
# 197246      ZWE    Africa     Zimbabwe  2022-06-26     255355.0       46.0
# 197247      ZWE    Africa     Zimbabwe  2022-06-27     255383.0       28.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 197243              90.571        5542.0         1.0                2.286
# 197244              79.429        5549.0         7.0                2.286
# 197245              79.429        5549.0         0.0                2.286
# 197246              79.143        5549.0         0.0                2.143
# 197247              78.857        5549.0         0.0                2.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 197243  ...             1.6          30.7                  36.791
# 197244  ...             1.6          30.7                  36.791
# 197245  ...             1.6          30.7                  36.791
# 197246  ...             1.6          30.7                  36.791
# 197247  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 197243                         1.7            61.49                    0.571
# 197244                         1.7            61.49                    0.571
# 197245                         1.7            61.49                    0.571
# 197246                         1.7            61.49                    0.571
# 197247                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 197243                                   NaN                          NaN
# 197244                                   NaN                          NaN
# 197245                                   NaN                          NaN
# 197246                                   NaN                          NaN
# 197247                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 197243               NaN                                      NaN
# 197244               NaN                                      NaN
# 197245               NaN                                      NaN
# 197246               NaN                                      NaN
# 197247               NaN                                      NaN
#
# [197248 rows x 67 columns]

# %%
df.isnull().sum()  #checking NaN for each column
# Out:
# iso_code                                           0
# continent                                      11438
# location                                           0
# date                                               0
# total_cases                                     7918
# new_cases                                       8168
# new_cases_smoothed                              9342
# total_deaths                                   26529
# new_deaths                                     26555
# new_deaths_smoothed                            27718
# total_cases_per_million                         8790
# new_cases_per_million                           9040
# new_cases_smoothed_per_million                 10209
# total_deaths_per_million                       27388
# new_deaths_per_million                         27414
# new_deaths_smoothed_per_million                28572
# reproduction_rate                              49473
# icu_patients                                  171137
# icu_patients_per_million                      171137
# hosp_patients                                 169904
# hosp_patients_per_million                     169904
# weekly_icu_admissions                         190864
# weekly_icu_admissions_per_million             190864
# weekly_hosp_admissions                        184508
# weekly_hosp_admissions_per_million            184508
# total_tests                                   117863
# new_tests                                     121847
# total_tests_per_thousand                      117863
# new_tests_per_thousand                        121847
# new_tests_smoothed                             93285
# new_tests_smoothed_per_thousand                93285
# positive_rate                                 101328
# tests_per_case                                103190
# tests_units                                    90462
# total_vaccinations                            142973
# people_vaccinated                             145533
# people_fully_vaccinated                       148036
# total_boosters                                171067
# new_vaccinations                              152742
# new_vaccinations_smoothed                      89499
# total_vaccinations_per_hundred                142973
# people_vaccinated_per_hundred                 145533
# people_fully_vaccinated_per_hundred           148036
# total_boosters_per_hundred                    171067
# new_vaccinations_smoothed_per_million          89499
# new_people_vaccinated_smoothed                 90467
# new_people_vaccinated_smoothed_per_hundred     90467
# stringency_index                               43900
# population                                      1189
# population_density                             21475
# median_age                                     34311
# aged_65_older                                  36034
# aged_70_older                                  35164
# gdp_per_capita                                 35412
# extreme_poverty                                91623
# cardiovasc_death_rate                          34695
# diabetes_prevalence                            26746
# female_smokers                                 74476
# male_smokers                                   76159
# handwashing_facilities                        117491
# hospital_beds_per_thousand                     52989
# life_expectancy                                12771
# human_development_index                        39091
# excess_mortality_cumulative_absolute          190533
# excess_mortality_cumulative                   190533
# excess_mortality                              190533
# excess_mortality_cumulative_per_million       190533
# dtype: int64

# %%
country_list=['United States','India','Germany']
df_plot=pd.DataFrame()

for each in country_list:
    df_plot[each]=np.array(df[df['location']==each].sum(axis=0))
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\3834787090.py:5: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\3834787090.py:5: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\3834787090.py:5: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
#selecting 3 countries into a dataframe
df_usa=df['location']=='United States'
df_ind=df['location']=='India'
df_ger=df['location']=='Germany'
df_list= df_usa | df_ind |df_ger
df_countries=df[df_list]

# %%
df_countries.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 66515      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 66516      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 66517      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 66518      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 66519      DEU    Europe  Germany  2020-01-31          5.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 66515                 NaN           NaN         NaN                  NaN  ...
# 66516                 NaN           NaN         NaN                  NaN  ...
# 66517                 NaN           NaN         NaN                  NaN  ...
# 66518                 NaN           NaN         NaN                  NaN  ...
# 66519                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 66515            28.2          33.1                     NaN
# 66516            28.2          33.1                     NaN
# 66517            28.2          33.1                     NaN
# 66518            28.2          33.1                     NaN
# 66519            28.2          33.1                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 66515                         8.0            81.33                    0.947
# 66516                         8.0            81.33                    0.947
# 66517                         8.0            81.33                    0.947
# 66518                         8.0            81.33                    0.947
# 66519                         8.0            81.33                    0.947
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 66515                                   NaN                          NaN
# 66516                                   NaN                          NaN
# 66517                                   NaN                          NaN
# 66518                                   NaN                          NaN
# 66519                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 66515               NaN                                      NaN
# 66516               NaN                                      NaN
# 66517               NaN                                      NaN
# 66518               NaN                                      NaN
# 66519               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
#plotting the cases spread for 3 countries
fig=px.line(df_countries, x= "date", y= "total_cases",color='location', title= "Covid Cases spread")
fig.show()
# Out:
# <div>                            <div id="56c7d4ad-5e4e-4893-8997-daa97b665589" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56c7d4ad-5e4e-4893-8997-daa97b665589")) {                    Plotly.newPlot(                        "56c7d4ad-5e4e-4893-8997-daa97b665589",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>total_cases=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09-30","2020-10-01 ...

# %%
#Figure 1 The relative cases overtime of Covid infectors 
df_countries['total_cases_per_population']=df_countries['total_cases']/df_countries['population'] #absolut Covid cases/population size
#plotting the relative spread for 3 countries
fig=px.line(df_countries, x= "date", y= "total_cases_per_population",color='location', title= "Covid Cases spread per population")
fig.update_xaxes(range=["2020-08-01","2022-06-25"])
fig.show()
#saving the plot
if not os.path.exists("../images"):
    os.mkdir("images")
    
fig.write_image("../images/figure1.jpeg")
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\496335320.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="1c286d37-41c4-4b65-8893-3c7366a940e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c286d37-41c4-4b65-8893-3c7366a940e7")) {                    Plotly.newPlot(                        "1c286d37-41c4-4b65-8893-3c7366a940e7",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>total_cases_per_population=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09- ...

# %%
cols=['people_fully_vaccinated']
df_countries.loc[:,cols] = df_countries.loc[:,cols].ffill() #to cover up for missing data
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\2810236936.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Figure 2 The vaccination rate (percentage of the population) over time 
df_countries['vaccination_rate']=df_countries['people_fully_vaccinated']/df_countries['population'] #absolut Covid cases/population size
#plotting the relative vaccination rate for 3 countries
fig=px.line(df_countries, x= "date", y= "vaccination_rate",color='location', title= "Covid vaccination rate per population")
fig.update_xaxes(range=["2021-03-01","2022-06-25"]) #to set the range of dates in a particular range
fig.update_yaxes(range=[0,1])
fig.write_image("../images/figure2.jpeg") #saving the figure plot
fig.show()
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_11600\2343277364.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="eebb6da6-ac36-44bd-9022-2c10a933d5fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eebb6da6-ac36-44bd-9022-2c10a933d5fa")) {                    Plotly.newPlot(                        "eebb6da6-ac36-44bd-9022-2c10a933d5fa",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>vaccination_rate=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09-30","2020- ...
